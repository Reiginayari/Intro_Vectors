# %% [markdown]
# 1. Solve $X$ given that:
# \begin{equation}
# A =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4 \\
# \end{bmatrix},
# B =
# \begin{bmatrix}
# -1 & 0 \\
# 1 & 1 \\
# \end{bmatrix}
# \end{equation}
# - $3X = A-2B$
# - $2(A-B+2X) = 3(X-B)$
# <br>
# <br>
# $SOLUTION:$ <br>
# $X = \frac{1}{3}(A-2B)$<br>
# \begin{equation}
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4 \\
# \end{bmatrix}
# -\frac{2}{3}
# \begin{bmatrix}
# -1 & 0 \\
# 1 & 1 \\
# \end{bmatrix}
# \end{equation}
# <br>
# \begin{equation}
# \begin{bmatrix}
# 1+2 & 2 \\
# 3-2 & 4-4 \\
# \end{bmatrix}
# +\frac{2}{3}
# \begin{bmatrix}
# -1 & 0 \\
# 1 & 1 \\
# \end{bmatrix}
# \end{equation}
# <br>
# \begin{equation}
# \begin{bmatrix}
# 3 & 2 \\
# 1 & 0 \\
# \end{bmatrix}
# +\frac{2}{3}
# \begin{bmatrix}
# 1 & 0 \\
# -1 & -1 \\
# \end{bmatrix}
# \end{equation}
# <br>
# \begin{equation}
# \begin{bmatrix}
# 3 + 2 & 2\\
# 1 - 2 & 0 \\
# \end{bmatrix}
# \end{equation}
# <br>
# \begin{equation}
# \begin{bmatrix}
# 5 & 2\\
# -1 & 0 \\
# \end{bmatrix}
# \end{equation}
# <br>
# $SOLUTION:$
# $2A-2B+4X=3X-3B$ <br>
# $2A+4X=3X-B$ <br>
# $4X-3X=-2A-B$ <br>
# $X=-2A-B$ <br>
# <br>
# \begin{equation}
# \begin{bmatrix}
# -1 & -4 \\
# -7 & -9 \\
# \end{bmatrix}
# \end{equation}
# <br>
# 2. Write $B$ as a linear combination of the other matrices, if possible. <br>
# \begin{equation}
# A_1 =
# \begin{bmatrix}
# 1 & 2 \\
# -1 & 1 \\
# \end{bmatrix},
# A_2 =
# \begin{bmatrix}
# 0 & 1 \\
# 2 & 1 \\
# \end{bmatrix},
# B =
# \begin{bmatrix}
# 2 & 5 \\
# 0 & 3 \\
# \end{bmatrix}
# \end{equation}
# <br><br>
# \begin{equation}
# A_1 =
# \begin{bmatrix}
# 1 & 0 \\
# 0 & 1 \\
# \end{bmatrix},
# A_2 =
# \begin{bmatrix}
# 0 & 1 \\
# 1 & 0 \\
# \end{bmatrix},
# A_3 =
# \begin{bmatrix}
# 1 & -1 \\
# 1 & 1 \\
# \end{bmatrix},
# B =
# \begin{bmatrix}
# 2 & 5 \\
# 0 & 3 \\
# \end{bmatrix}
# \end{equation}
# <br>
# $B = c_1A_1+c_2A_2+c_3A_3$ <br>
# $B = 2A_1+A_2$ <br>
# $B = 2A_1+3A_2-3A_3$<br>
# <br>
# 3. Given the following: <br>
# \begin{equation}
# A =
# \begin{bmatrix}
# 1 & 2 \\
# 2 & 6 \\
# \end{bmatrix},
# b_1 =
# \begin{bmatrix}
# 3 \\
# 5 \\
# \end{bmatrix},
# b_2 =
# \begin{bmatrix}
# -1 \\
# 2 \\
# \end{bmatrix},
# b_3 =
# \begin{bmatrix}
# 2 \\
# 0 \\
# \end{bmatrix}
# \end{equation}
# - Find $A^{-1}$, and use this to solve for $Ax=b_1,Ax=b_2,Ax=b_3$
# - Solve all three linear systems by row reducing the augmented matrix:
# \begin{equation}
# \begin{bmatrix}
# \begin{array}{c|ccc}
# A &
# b_1 &
# b_2 &
# b_3 \\
# \end{array}
# \end{bmatrix}
# \end{equation} <br>
# $Solving Ax=b_1:$ <br>
# \begin{equation}
# \begin{bmatrix}
# x_1 \\
# x_2 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 \\
# 1 \\
# \end{bmatrix}
# \end{equation}
# <br>
# $Solving Ax=b_2:$ <br>
# \begin{equation}
# \begin{bmatrix}
# x_1 \\
# x_2 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 2 \\
# -1 \\
# \end{bmatrix}
# \end{equation}
# <br>
# <br>
# $Solving Ax=b_3:$ <br>
# \begin{equation}
# \begin{bmatrix}
# x_1 \\
# x_2 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 3 \\
# -1 \\
# \end{bmatrix}
# \end{equation}
# <br>
# Row Reducing the Augmented Matrix: <br>
# 1. $[A|b_1] $=
# \begin{bmatrix}
# 1 & 0 | 4 \\
# 0 & 1 | -\frac{1}{2}\\
# \end{bmatrix}
# <br>
# 2. $[A|b_2] $=
# \begin{bmatrix}
# 1 & 0 | 2 \\
# 0 & 1 | -1\\
# \end{bmatrix}
# <br>
# 3. $[A|b_3] $=
# \begin{bmatrix}
# 1 & 0 | 3 \\
# 0 & 1 | -\frac{1}{2}\\
# \end{bmatrix}
# 4. In each given, determine if $b$ in in $col(A)$, and $w$ is in $row(A)$ <br>
# \begin{equation}
# A =
# \begin{bmatrix}
# 1 & 0 & -1 \\
# 1 & 1 & 1 \\
# \end{bmatrix},
# b =
# \begin{bmatrix}
# 3 \\
# 2 \\
# \end{bmatrix},
# w =
# \begin{bmatrix}
# -1 &
# 1 &
# 1
# \end{bmatrix},
# \end{equation}
# -
# \begin{equation}
# A =
# \begin{bmatrix}
# 1 & 1 & -1 \\
# 1 & 3 & 0 \\
# 3 & -1 & -5 \\
# \end{bmatrix},
# b =
# \begin{bmatrix}
# 1 \\
# 2 \\
# 1 \\
# \end{bmatrix},
# w =
# \begin{bmatrix}
# 1 &
# -3 &
# -3
# \end{bmatrix},
# \end{equation}
# 5. Find the rank and nullity of:
# \begin{bmatrix}
# 2 & 4 & 0 & 0 & 1 \\
# 6 & 3 & 5 & 1 & 0 \\
# 1 & 0 & 2 & 2 & 5 \\
# 1 & 1 & 1 & 1 & 1 \\
# \end{bmatrix},
